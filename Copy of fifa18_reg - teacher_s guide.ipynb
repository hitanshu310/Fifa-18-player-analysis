# %% [markdown]
# ### IMPORT LIBRARIES

# %%
## import numpy, pandas


## your code here, to be deleted
import numpy as np
import pandas as pd
from pandas import read_csv

# %% [markdown]
# ### IMPORT DATASET

# %%
## import fifa18 dataset

df = 
df

## to be deleted, only for speaker reference
df = read_csv('FIFA18v2.csv')
df
# Out:
#                     Name  Age  \
# 0               L. Messi   30
# 1      Cristiano Ronaldo   32
# 2                 Neymar   25
# 3              L. Suárez   30
# 4               M. Neuer   31
# 5                 De Gea   26
# 6           K. De Bruyne   26
# 7         R. Lewandowski   28
# 8              E. Hazard   26
# 9               T. Kroos   27
# 10            M. Hummels   28
# 11            G. Higuaín   29
# 12          Sergio Ramos   31
# 13             P. Dybala   23
# 14              J. Oblak   24
# 15           T. Courtois   25
# 16             L. Modrić   31
# 17           David Silva   31
# 18             S. Agüero   29
# 19          G. Chiellini   32
# 20             G. Buffon   39
# 21              N. Kanté   26
# 22               H. Kane   23
# 23              P. Pogba   24
# 24          A. Griezmann   26
# 25            C. Eriksen   25
# 26                Thiago   26
# 27            A. Sánchez   28
# 28              D. Godín   31
# 29             E. Cavani   30
# ...

# %%
## dropping non-performing features
df_copy = df.copy()
df_copy.drop(df_copy.columns[[2,3,4,7,8]], axis=1,inplace=True)
df_copy.head()
# Out:
#                 Name  Age  Overall  Potential        Value      Wage  Special  \
# 0           L. Messi   30       94         94  118500000.0  565000.0     2161
# 1  Cristiano Ronaldo   32       94         94   95500000.0  565000.0     2228
# 2             Neymar   25       92         93  119500000.0  280000.0     2105
# 3          L. Suárez   30       92         92   97000000.0  510000.0     2321
# 4           M. Neuer   31       92         92   61000000.0  230000.0     1487
#
#    Acceleration  Aggression  Agility   ...     Reactions  Short Passing  \
# 0            92          48       90   ...            95             88
# 1            89          63       89   ...            96             83
# 2            94          56       96   ...            88             82
# 3            88          87       86   ...            93             83
# 4            56          29       51   ...            85             55
#
# ...

# %%
## This is how the data looks like now
df = df_copy
df.head()
# Out:
#                 Name  Age  Overall  Potential        Value      Wage  Special  \
# 0           L. Messi   30       94         94  118500000.0  565000.0     2161
# 1  Cristiano Ronaldo   32       94         94   95500000.0  565000.0     2228
# 2             Neymar   25       92         93  119500000.0  280000.0     2105
# 3          L. Suárez   30       92         92   97000000.0  510000.0     2321
# 4           M. Neuer   31       92         92   61000000.0  230000.0     1487
#
#    Acceleration  Aggression  Agility   ...     Reactions  Short Passing  \
# 0            92          48       90   ...            95             88
# 1            89          63       89   ...            96             83
# 2            94          56       96   ...            88             82
# 3            88          87       86   ...            93             83
# 4            56          29       51   ...            85             55
#
# ...

# %% [markdown]
# ### SETTING NAME AS INDEX

# %%
## Next we will be using name as an index so that we ca get the data of all players easily

df.set_index()

##  to be deleted
df.set_index('Name',inplace= True)
df.head()
# Out:
#                    Age  Overall  Potential        Value      Wage  Special  \
# Name
# L. Messi            30       94         94  118500000.0  565000.0     2161
# Cristiano Ronaldo   32       94         94   95500000.0  565000.0     2228
# Neymar              25       92         93  119500000.0  280000.0     2105
# L. Suárez           30       92         92   97000000.0  510000.0     2321
# M. Neuer            31       92         92   61000000.0  230000.0     1487
#
#                    Acceleration  Aggression  Agility  Balance   ...     \
# Name                                                            ...
# L. Messi                     92          48       90       95   ...
# Cristiano Ronaldo            89          63       89       63   ...
# Neymar                       94          56       96       82   ...
# L. Suárez                    88          87       86       78   ...
# M. Neuer                     56          29       51       35   ...
#
# ...

# %%
## seee if it's working
df.loc['L. Messi']
# Out:
# Age                        30.0
# Overall                    94.0
# Potential                  94.0
# Value               118500000.0
# Wage                   565000.0
# Special                  2161.0
# Acceleration               92.0
# Aggression                 48.0
# Agility                    90.0
# Balance                    95.0
# Ball Control               96.0
# Composure                  97.0
# Crossing                   77.0
# Curve                      90.0
# Dribbling                  97.0
# FK Accuracy                92.0
# Finishing                  95.0
# GK Diving                   6.0
# GK Handling                11.0
# GK Kicking                 15.0
# GK Positioning             14.0
# GK Reflexes                 8.0
# Heading Accuracy           71.0
# Interceptions              22.0
# Jumping                    67.0
# Long Passing               87.0
# Long Shots                 88.0
# Marking                    13.0
# Penalties                  75.0
# ...

# %% [markdown]
# ### SEPARATING FEATURES AND LABELS

# %%
y = 
X = 


## So, are you going to write all the columns, try using df.columns and see what you get
## to be deleted
y = df['Overall']
X = df[df.columns[5:40]]

# %% [markdown]
# ### SPLITTING THE DATA INTO TRAINING AND TESTING SET

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = 

## to be deleted
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state = 1)

# %% [markdown]
# ### TRYING SIMPLE LINEAR REGRESSION

# %%
from sklearn import linear_model
import matplotlib.pyplot as plt
reg = linear_model.LinearRegression()

# %%
from sklearn.metrics import mean_squared_error

# %%
## plot learning curve









## Now interpret, overfitting, underfitting etc. from learning curve

## to be deleted, only for reference
i = 100
train_err = []
test_err = []
i_list = []
while(i <= len(X_train)):
    X_train_lc = X_train.iloc[0:i]
    y_train_lc = y_train.iloc[0:i]
    reg.fit(X_train_lc,y_train_lc)
    y_pred_test = reg.predict(X_test)
    y_pred_train = reg.predict(X_train_lc)
    train_err.append(mean_squared_error(y_train_lc,y_pred_train))
    test_err.append(mean_squared_error(y_pred_test,y_test))
    i_list.append(i)
    i = i + 500
plt.plot(i_list,train_err)    
plt.plot(i_list,test_err)


## The model is underfitting as more no. of samples is not improving the accuracy.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn import preprocessing as pre

# %% [markdown]
# ### USING POLYNOMIAL FEATURES

# %%
## let's start with 2


poly = 
X_poly
print(X_poly)



## for reference to be deleted
poly = PolynomialFeatures(degree = 2)
X_poly = poly.fit_transform(X)
X_poly
# Out:
# array([[1.000e+00, 2.161e+03, 9.200e+01, ..., 8.464e+03, 7.912e+03,
#         7.396e+03],
#        [1.000e+00, 2.228e+03, 8.900e+01, ..., 7.225e+03, 7.480e+03,
#         7.744e+03],
#        [1.000e+00, 2.105e+03, 9.400e+01, ..., 6.889e+03, 6.889e+03,
#         6.889e+03],
#        ...,
#        [1.000e+00, 1.155e+03, 5.400e+01, ..., 8.410e+02, 7.830e+02,
#         7.290e+02],
#        [1.000e+00, 9.760e+02, 4.200e+01, ..., 3.610e+02, 3.420e+02,
#         3.240e+02],
#        [1.000e+00, 1.386e+03, 6.800e+01, ..., 2.304e+03, 1.776e+03,
#         1.369e+03]])

# %%
## splitting
X_poly_train, X_poly_test, y_train, y_test = train_test_split(X_poly,y, random_state = 1)

# %%
from sklearn import preprocessing as pre
scaler = pre.StandardScaler()
X_poly = scaler.fit_transform(X_poly)

# %%
## draw learning curve









## for reference, to be deleted
i = 1000
train_err = []
test_err = []
i_list = []
while(i <= len(X_train)):
    X_poly_train_lc = X_poly_train[0:i]
    y_train_lc = y_train.iloc[0:i]
    reg.fit(X_poly_train_lc,y_train_lc)
    y_pred_test = reg.predict(X_poly_test)
    y_pred_train = reg.predict(X_poly_train_lc)
    train_err.append(mean_squared_error(y_train_lc,y_pred_train))
    test_err.append(mean_squared_error(y_pred_test,y_test))
    i_list.append(i)
    i = i + 1000
plt.plot(i_list,train_err)
plt.plot(i_list,test_err)
plt.ylim((0,10))
# Out:
# (0, 10)
